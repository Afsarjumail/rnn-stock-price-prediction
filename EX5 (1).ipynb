# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras import layers
from keras.models import Sequential

# %%
dataset_train = pd.read_csv('trainset.csv')

# %%
dataset_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dataset_train.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-01-02  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  2013-01-03  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  2013-01-04  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  2013-01-07  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  2013-01-08  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900

# %%
train_set = dataset_train.iloc[:,1:2].values
type(train_set)
# Out:
# numpy.ndarray

# %%
train_set.shape
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(train_set)

# %%
training_set_scaled.shape
X_train_array = []
y_train_array = []
for i in range(60, 1259):
  X_train_array.append(training_set_scaled[i-60:i,0])
  y_train_array.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train_array), np.array(y_train_array)
X_train1 = X_train.reshape((X_train.shape[0], X_train.shape[1],1))

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
X_train.shape
length = 60
n_features = 1
model = models.Sequential()
model.add(layers.SimpleRNN(50,input_shape=(60,1)))
model.add(layers.Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
print("Name: Afsar jumail S  Register Number: 212222240004")
model.summary()

model.fit(X_train1,y_train,epochs=100, batch_size=32)

dataset_test = pd.read_csv('testset.csv')
test_set = dataset_test.iloc[:,1:2].values
test_set.shape
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis=0)
# Out:
# Name: Afsar jumail S  Register Number: 212222240004
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 50)                2600
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2651 (10.36 KB)
# Trainable params: 2651 (10.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 38/38 [==============================] - 2s 12ms/step - loss: 0.0193
# Epoch 2/100
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 3/100
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 4/100
# 38/38 [==============================] - 0s 12ms/step - loss: 8.7290e-04
# Epoch 5/100
# 38/38 [==============================] - 0s 11ms/step - loss: 7.1698e-04
# Epoch 6/100
# 38/38 [==============================] - 0s 12ms/step - loss: 6.5360e-04
# Epoch 7/100
# 38/38 [==============================] - 0s 11ms/step - loss: 5.2566e-04
# Epoch 8/100
# 38/38 [==============================] - 0s 11ms/step - loss: 5.1486e-04
# Epoch 9/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.8367e-04
# Epoch 10/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.6416e-04
# Epoch 11/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.4873e-04
# Epoch 12/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.4891e-04
# Epoch 13/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.7340e-04
# Epoch 14/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.6805e-04
# Epoch 15/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.4678e-04
# Epoch 16/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.6890e-04
# Epoch 17/100
# 38/38 [==============================] - 1s 14ms/step - loss: 3.5165e-04
# Epoch 18/100
# 38/38 [==============================] - 1s 19ms/step - loss: 3.3042e-04
# Epoch 19/100
# 38/38 [==============================] - 1s 20ms/step - loss: 4.1430e-04
# Epoch 20/100
# 38/38 [==============================] - 1s 21ms/step - loss: 3.0435e-04
# Epoch 21/100
# 38/38 [==============================] - 1s 14ms/step - loss: 3.2123e-04
# Epoch 22/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.5946e-04
# Epoch 23/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.0023e-04
# Epoch 24/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.7228e-04
# Epoch 25/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.2518e-04
# Epoch 26/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.8811e-04
# Epoch 27/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.8157e-04
# Epoch 28/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.8271e-04
# Epoch 29/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.6961e-04
# Epoch 30/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.4849e-04
# Epoch 31/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.6825e-04
# Epoch 32/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.5600e-04
# Epoch 33/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.1775e-04
# Epoch 34/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.5894e-04
# Epoch 35/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.4965e-04
# Epoch 36/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.7737e-04
# Epoch 37/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.4719e-04
# Epoch 38/100
# 38/38 [==============================] - 0s 12ms/step - loss: 3.4345e-04
# Epoch 39/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.2112e-04
# Epoch 40/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.3636e-04
# Epoch 41/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.2247e-04
# Epoch 42/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.4715e-04
# Epoch 43/100
# 38/38 [==============================] - 1s 13ms/step - loss: 2.3771e-04
# Epoch 44/100
# 38/38 [==============================] - 1s 19ms/step - loss: 2.4106e-04
# Epoch 45/100
# 38/38 [==============================] - 1s 18ms/step - loss: 2.6981e-04
# Epoch 46/100
# 38/38 [==============================] - 1s 19ms/step - loss: 2.4591e-04
# Epoch 47/100
# 38/38 [==============================] - 1s 19ms/step - loss: 2.2270e-04
# Epoch 48/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.2470e-04
# Epoch 49/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.0581e-04
# Epoch 50/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0749e-04
# Epoch 51/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.0146e-04
# Epoch 52/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1422e-04
# Epoch 53/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.9837e-04
# Epoch 54/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1009e-04
# Epoch 55/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9906e-04
# Epoch 56/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.9877e-04
# Epoch 57/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0452e-04
# Epoch 58/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.0794e-04
# Epoch 59/100
# 38/38 [==============================] - 1s 24ms/step - loss: 2.1882e-04
# Epoch 60/100
# 38/38 [==============================] - 1s 29ms/step - loss: 2.0565e-04
# Epoch 61/100
# 38/38 [==============================] - 1s 24ms/step - loss: 2.1907e-04
# Epoch 62/100
# 38/38 [==============================] - 1s 25ms/step - loss: 2.0266e-04
# Epoch 63/100
# 38/38 [==============================] - 1s 22ms/step - loss: 1.9830e-04
# Epoch 64/100
# 38/38 [==============================] - 1s 16ms/step - loss: 2.1086e-04
# Epoch 65/100
# 38/38 [==============================] - 1s 18ms/step - loss: 2.0489e-04
# Epoch 66/100
# 38/38 [==============================] - 1s 18ms/step - loss: 1.8080e-04
# Epoch 67/100
# 38/38 [==============================] - 1s 20ms/step - loss: 1.9246e-04
# Epoch 68/100
# 38/38 [==============================] - 1s 15ms/step - loss: 1.9857e-04
# Epoch 69/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9074e-04
# Epoch 70/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8436e-04
# Epoch 71/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8576e-04
# Epoch 72/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8893e-04
# Epoch 73/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8943e-04
# Epoch 74/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.2011e-04
# Epoch 75/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8915e-04
# Epoch 76/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8315e-04
# Epoch 77/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8180e-04
# Epoch 78/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8614e-04
# Epoch 79/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8953e-04
# Epoch 80/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.7833e-04
# Epoch 81/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.1736e-04
# Epoch 82/100
# 38/38 [==============================] - 0s 11ms/step - loss: 2.2022e-04
# Epoch 83/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.9097e-04
# Epoch 84/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.9226e-04
# Epoch 85/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8631e-04
# Epoch 86/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7935e-04
# Epoch 87/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7619e-04
# Epoch 88/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7817e-04
# Epoch 89/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.8181e-04
# Epoch 90/100
# 38/38 [==============================] - 0s 13ms/step - loss: 1.6531e-04
# Epoch 91/100
# 38/38 [==============================] - 1s 18ms/step - loss: 1.8957e-04
# Epoch 92/100
# 38/38 [==============================] - 1s 18ms/step - loss: 2.1121e-04
# Epoch 93/100
# 38/38 [==============================] - 1s 19ms/step - loss: 1.7712e-04
# Epoch 94/100
# 38/38 [==============================] - 1s 20ms/step - loss: 1.6687e-04
# Epoch 95/100
# 38/38 [==============================] - 1s 13ms/step - loss: 1.7852e-04
# Epoch 96/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.7792e-04
# Epoch 97/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8277e-04
# Epoch 98/100
# 38/38 [==============================] - 0s 11ms/step - loss: 1.7446e-04
# Epoch 99/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.8102e-04
# Epoch 100/100
# 38/38 [==============================] - 0s 12ms/step - loss: 1.7226e-04

# %%
inputs = dataset_total.values
inputs = inputs.reshape(-1,1)
inputs_scaled=sc.transform(inputs)
X_test = []
for i in range(60,1384):
  X_test.append(inputs_scaled[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
X_test.shape

predicted_stock_price_scaled = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price_scaled)

print("Name: Afsar jumail S Register Number: 212222240004")
plt.plot(np.arange(0,1384),inputs, color='red', label = 'Test(Real) Google stock price')
plt.plot(np.arange(60,1384),predicted_stock_price, color='blue', label = 'Predicted Google stock price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# 42/42 [==============================] - 1s 11ms/step
# Name: Afsar jumail S Register Number: 212222240004
